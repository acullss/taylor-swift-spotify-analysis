# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <p style="text-align:center;">
         <svg width='600' height='200'>
            <filter id='money'>
               <feMorphology in='SourceGraphic' operator='dilate' radius='2' result='expand'/>
               <feOffset in='expand' dx='1' dy='1' result='shadow_1'/>
               <feOffset in='expand' dx='2' dy='2' result='shadow_2'/>
               <feOffset in='expand' dx='3' dy='3' result='shadow_3'/>
               <feOffset in='expand' dx='4' dy='4' result='shadow_4'/>
               <feOffset in='expand' dx='5' dy='5' result='shadow_5'/>
               <feOffset in='expand' dx='6' dy='6' result='shadow_6'/>
               <feOffset in='expand' dx='7' dy='7' result='shadow_7'/>
               <feMerge result='shadow'>
                  <feMergeNode in='expand'/>
                  <feMergeNode in='shadow_1'/>
                  <feMergeNode in='shadow_2'/>
                  <feMergeNode in='shadow_3'/>
                  <feMergeNode in='shadow_4'/>
                  <feMergeNode in='shadow_5'/>
                  <feMergeNode in='shadow_6'/>
                  <feMergeNode in='shadow_7'/>
               </feMerge>
               <feFlood flood-color='#ebe7e0'/>
               <feComposite in2='shadow' operator='in' result='shadow'/>
               <feMorphology in='shadow' operator='dilate' radius='1' result='border'/>
               <feFlood flood-color='#35322a' result='border_color'/>
               <feComposite in2='border' operator='in' result='border'/>
               <feOffset in='border' dx='1' dy='1' result='secondShadow_1'/>
               <feOffset in='border' dx='2' dy='2' result='secondShadow_2'/>
               <feOffset in='border' dx='3' dy='3' result='secondShadow_3'/>
               <feOffset in='border' dx='4' dy='4' result='secondShadow_4'/>
               <feOffset in='border' dx='5' dy='5' result='secondShadow_5'/>
               <feOffset in='border' dx='6' dy='6' result='secondShadow_6'/>
               <feOffset in='border' dx='7' dy='7' result='secondShadow_7'/>
               <feOffset in='border' dx='8' dy='8' result='secondShadow_8'/>
               <feOffset in='border' dx='9' dy='9' result='secondShadow_9'/>
               <feOffset in='border' dx='10' dy='10' result='secondShadow_10'/>
               <feOffset in='border' dx='11' dy='11' result='secondShadow_11'/>
               <feMerge result='secondShadow'>
                  <feMergeNode in='border'/>
                  <feMergeNode in='secondShadow_1'/>
                  <feMergeNode in='secondShadow_2'/>
                  <feMergeNode in='secondShadow_3'/>
                  <feMergeNode in='secondShadow_4'/>
                  <feMergeNode in='secondShadow_5'/>
                  <feMergeNode in='secondShadow_6'/>
                  <feMergeNode in='secondShadow_7'/>
                  <feMergeNode in='secondShadow_8'/>
                  <feMergeNode in='secondShadow_9'/>
                  <feMergeNode in='secondShadow_10'/>
                  <feMergeNode in='secondShadow_11'/>
               </feMerge>
               <feImage x='0' y='0' width='600' height='200' xlink:href='https://s3-us-west-2.amazonaws.com/s.cdpn.io/78779/stripes.svg'/>
               <feComposite in2='secondShadow' operator='in' result='secondShadow'/>
               <feMerge>
                  <feMergeNode in='secondShadow'/>
                  <feMergeNode in='border'/>
                  <feMergeNode in='shadow'/>
                  <feMergeNode in='SourceGraphic'/>
               </feMerge>
            </filter>
            <text dominant-baseline='middle' text-anchor='middle' x='50%' y='50%' >
               Taylor Swift
            </text>
      <p style="text-align:center;">
      <subtext>Spotify charts: Exploratory Data Analysis</subtext>
      </p>
      </svg>
      </p>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      text {
      fill: #35322a;
      filter: url('#money');
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 98px;
      font-weight: 100;
      }
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
     
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %% [markdown]
# <p style="text-align:center;"><img src="https://www.rollingstone.com/wp-content/uploads/2019/08/taylor-swift-ultimate-album-sheff.jpg" alt="drawing" width="70%" /></p>

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <subtext>This notebook implements the EDA using spark</subtext>
      <img src = "https://www.vectorlogo.zone/logos/apache_spark/apache_spark-ar21.png" width="20%"/>
      <rtext>
      <li>Spark is built to perform EDA on petabyte-scale data</li>  
<li>It adapts to the execution plan at runtime(lazy evaluation)</li>
<li>Spark also processes everything in RAM which makes it very fast. However if no sufficient RAM is available, it is capable of executing the remaining on the disk.</li>
<li>Here we are working with a 3.4GB CSV file! Spark helps to speed up the sql queries executed on millions of rows of data here.</li>
<li>It has distributed data processing engine. </li>
<li>It can be used from multiple languages and databases as well</li>
<li>We can perform graph analytics</li>
<li>It is fault tolerent</li>
<li>Supports multiple storage formats (here csv)</li>
<li>It has pandas API as well </li>
<li>Follows SQL closely</li></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
# !pip install pyspark

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
import pyspark.sql.types as t
import pyspark.sql.functions as f
import seaborn as sns
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext>A <strong>SparkSession</strong> can be used create:
      <li>DataFrame</li>
      <li>Register DataFrame as tables</li>
      <li>Execute SQL over tables</li>
      <li>Cache tables</li>
      <li>Read parquet files</li>
      </rtext>
      <rtext>To create a SparkSession, use the following builder pattern:</rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark = (SparkSession.builder.config("spark.driver.memory","4g").config("spark.driver.maxResultSize", "4g").getOrCreate())

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext>
Now, we need to import our data. 
We are specifying the desire to use dataset csv format. 
 
      <li><strong>“header”</strong> here set to true signifies the first row has column names. </li>
      <li><strong>“inferSchema”</strong> instructs Spark to attempt to infer the schema of the CSV</li>
      </rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
# import dataframe
df = spark.read.csv(path='../input/spotify-charts/charts.csv', inferSchema=True, header=True)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext>
<li>We cannot perform our analysis with all the datatype string right?
Thus here we parse the datatypes using the format below.</li>
<li>Also, here are the following <strong>datatypes supported by Spark</strong>:
<a href="https://spark.apache.org/docs/3.0.0-preview2/sql-ref-datatypes.html">Spark Daatypes</a></li>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
# setting the schema

df = df.withColumn("rank", f.col("rank").cast(t.LongType())).withColumn("date", f.col("date").cast(t.DateType())).withColumn("streams", f.col("streams").cast(t.IntegerType()))

# %%
df

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext>
<li>To perform analysis, we will be using spark sql library.  For that, we create a temp table</li>
<li>The reason to use the <strong>registerTempTable( tableName )</strong> method for a DataFrame, is so that in addition to being able to use the Spark-provided methods of a DataFrame</li>
<li>Using this, we can also issue SQL queries via the sqlContext. sql( sqlQuery ) method, that use that DataFrame as an SQL table.</li>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
# Register a temp table
df.registerTempTable("charts")

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <p style="text-align:center;">
      <subtext>Exploratory Data Analysis</subtext>
      </p>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
     
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      1. Get the range of timeline of the data
      
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT MIN(date) begin, MAX(date) end 
FROM charts 
WHERE chart = 'top200';
''').toPandas()

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      2. From the following query, we see that the artists are listed in form of CSV</strong>
      <li>Since werae interested in the EDA of the songs by Taylor Swift, we will use WHERE LIKE functionaly ahead.</li>
      
      </rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT * 
FROM charts 
WHERE chart='top200' 
LIMIT 10;
''').toPandas()

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      3. Get total number of entries by all the singers in TOP 200
      
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT COUNT(*) n
FROM charts 
WHERE chart = 'top200';
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
   <p  style="text-align:center;">
      <rtext>We can perform a variety of EDA on the given dataset.<strong>
However being a Swiftie, I am personalizing my analysis.
      </strong></rtext>
      
    </p>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %% [markdown]
# <p style="text-align:center;"><img src="https://i.pinimg.com/736x/13/eb/bc/13ebbcd2fb8da9865872bc4e2eff784b.jpg" alt="drawing" width="60%" /></p>

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      4. Total Number of songs by TS has appeared in top 200 
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT count(distinct title) NoOfSongs 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart = 'top200';
''').toPandas().head()

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      5. Counting number of times Taylor Swift appeared in the TOP 200 trend
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT Count(*) N_InTop200 
FROM charts 
WHERE artist 
LIKE '%Taylor Swift%' 
AND chart = 'top200';
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      6. Number of times TS appeared in top 200 by listing the all artists
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT artist, count(artist) count 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart='top200' 
GROUP BY artist 
ORDER BY count desc;
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <subtext>Listing Taylor's TOP 10!</subtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      color: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
     
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT title, SUM(streams) streams 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND streams IS NOT NULL 
GROUP BY title 
ORDER BY streams DESC 
LIMIT 10;''').toPandas().head(10)

# %% [markdown]
# <h3 style="text-align:center;"><i>click on the images to stream through the vibe</i></h3>
# <div class="row" style="text-align:center;">
# <div class="column">
# <a href="https://open.spotify.com/track/55n9yjI6qqXh5F2mYvUc2y?si=tDgunNq5TImrHumD6D7jMg&utm_source=copy-link"><img src="https://i.pinimg.com/originals/e7/69/cd/e769cdfedbeedf4f6197b5967986d096.jpg" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/6RRNNciQGZEXnqk8SQ9yv5?si=AMbXCbiHRFONBJyaun4Fow&utm_source=copy-link"><img src="https://headlineplanet.com/home/wp-content/uploads/2019/06/Taylor-Swift-Calm-Down-Art.jpg" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/2Rk4JlNc2TPmZe2af99d45?si=h6re5vpmSgGGoz5mhS9hBQ&utm_source=copy-link"><img src="https://upload.wikimedia.org/wikipedia/en/thumb/0/01/Taylor_Swift_-_Me%21.png/220px-Taylor_Swift_-_Me%21.png" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/1P17dC1amhFzptugyAO7Il?si=7NFeynVnTJKqL6vIliZQpg&utm_source=copy-link"><img src="https://cf.shopee.ph/file/c913d26c69822937eda10941a8442150" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/0lx2cLdOt3piJbcaXIV74f?si=KtiGKJrZTAmePCgpN5l_lw&utm_source=copy-link"><img src="https://i.ytimg.com/vi/tcuD3ms_SWg/maxresdefault.jpg" alt="drawing" width="23%" /></a>
# </div>
# <div class="column">
# <a href="https://open.spotify.com/track/1dGr1c8CrMLDpV6mPbImSI?si=bQ8q6klQTHWrkertPcYavQ&utm_source=copy-link"><img src="https://upload.wikimedia.org/wikipedia/en/thumb/c/cd/Taylor_Swift_-_Lover.png/220px-Taylor_Swift_-_Lover.png" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/4R2kfaDFhslZEMJqAFNpdd?si=ZE_8F3H0QjKf37fs7MFGIA&utm_source=copy-link"><img src="https://i.pinimg.com/originals/fd/26/d9/fd26d924e4d92eb4c030897f431b3fc8.jpg" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/2yLa0QULdQr0qAIvVwN6B5?si=R8V0C6tvSYKPxLueXOMObQ&utm_source=copy-link"><img src="https://lastfm.freetls.fastly.net/i/u/ar0/aeec64bffb7de71c7e8b0a85739294c5.jpg" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/6NFyWDv5CjfwuzoCkw47Xf?si=CHWyKwstTUqtkbGaz6ywRw&utm_source=copy-link"><img src="https://i.pinimg.com/originals/06/bb/da/06bbda3eb2a8a9291d3f13ed28b55114.jpg" alt="drawing" width="23%" /></a><a href="https://open.spotify.com/track/6NFyWDv5CjfwuzoCkw47Xf?si=CHWyKwstTUqtkbGaz6ywRw&utm_source=copy-link"><img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/f4f02ab3-f211-4f94-a56a-bedff443c1f5/de2lia6-706c4f01-c311-43e4-af91-003bb4b54704.jpg?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..FrAE9NFbLuhcQLiV_CtNmVG35WDET3opNxcrTpmeObg" alt="drawing" width="23%" /></a>
# </div>
# </div>

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      7. Seeing how many times each song has appeared in top 200
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT title, count(title) AS count 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart = 'top200' 
GROUP BY title 
ORDER BY count DESC;
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      8. Number of days each song was on the chart
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT title, count(*) AS days 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart = 'top200' 
GROUP BY title 
ORDER BY days DESC;
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      9. Getting the highest ranks the songs have attained and the number of times they have been there in that position
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      color: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT title, MIN(rank) rank, count(rank) count 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart = 'top200' 
AND rank <=5 
GROUP BY title;
''').toPandas().head(20)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      10. Total how many times has Taylor been on the 1st rank
      </strong></rtext>
      <img src="https://parishkar.org/images/award.gif" width="15%"></img>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT count(*) Rank1 
FROM charts 
WHERE artist LIKE '%Taylor Swift%' 
AND chart = 'top200' 
AND rank = 1;
''').toPandas().head(10)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      11. Looking at the trends of few of my favourite songs over the course of time
      </strong></rtext>
      <img src="https://www.readersdigest.co.uk/media/NewFolder/music.gif" width="13%"/>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
q = spark.sql('''
SELECT title,YEAR(date) year ,date ,rank, region 
FROM charts 
WHERE title IN ('Love Story (Taylor’s Version)', 'Delicate', 'Lover') 
AND chart='top200'
ORDER BY rank ASC;''').toPandas()
q.head(20)

# %%
fig, axes = plt.subplots(figsize=(20,7))
sns.lineplot('date', 'rank', data=q, hue='title', ci=None).set_title('Trends in Top 200')

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <subtext>Inference</subtext>
      <rtext>
      <li>Delicate has been trending in top 200 from 2018 till mid 2020s.</li>
      <li>While Lover has been trending since mid 2018 till today. It feels fabulous to listen to such evergreen songs.</li>
      <li>Love Story on the other hand was on trend since 202</li>
      </rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>12. Lets try looking at the trends of the same songs in "Viral 50" chart</strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
q = spark.sql('''
SELECT title,date ,rank, region 
FROM charts 
WHERE title IN ('Love Story (Taylor’s Version)', 'Delicate', 'Lover') 
AND chart='viral50';
''').toPandas()
q.head(20)

# %%
fig, axes = plt.subplots(figsize=(20,7))
sns.lineplot('date', 'rank', data=q, hue='title', ci=None).set_title('Trends in Viral 50')

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <subtext>Inference</subtext></br>
      <rtext>
      We can see few clear differences in the trends of top 200 and viral 50:
      <li>Lover has been a top 50 viral song since 2017(and back) till today!</li>
      <li>Delicate faded from its viral popularity in somewhere mid 2020.</li>
      <li>Love Story clearly was on the viral list for quiet shorter period of time in 2021</li>
      </rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <rtext><strong>
      13. Highest, Lowest and the mean rank of the songs
      </strong></rtext>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      rtext{
      fill: #35322a;
      font-family: 'Georgia', serif;
      font-size: 17px;
      font-weight: 10;
      }
   </style>
   </head>
</html>
"""
HTML(html_contents)

# %%
spark.sql('''
SELECT Title, MIN(rank) Highest, MAX(rank) Lowest, AVG(rank) Avg 
FROM charts 
WHERE artist like '%Taylor Swift%' 
AND chart='top200' 
GROUP BY title 
ORDER BY Highest;
''').toPandas().head(20)

# %% [markdown]
# <p style="text-align:center;"><img src="https://www.knowol.com/wp-content/uploads/2016/09/taylor-swift-inspirational-quote-8.jpg" width="70%"/></p>

# %%
from IPython.core.display import display, HTML, Javascript
html_contents ="""
<!DOCTYPE html>
<html lang="en">
   <head>
   <body>
      <p style="text-align:center;">
      <subtext>Thank You =)</subtext>
      </p>
   </body>
   <style>
      @import url('https://fonts.googleapis.com/css?family=Playfair+Display:900');
      subtext{
      fill: #35322a;
      font-family: 'Playfair Display', 'Georgia', serif;
      font-size: 30px;
      font-weight: 20;
      }
      html {
      align-items: center;
      background: #ebe7e0;
      display: flex;
      justify-content: center;
      }
     
   </style>
   </head>
</html>
"""
HTML(html_contents)
